# %%
import pandas as pd

# %%
df_wits=pd.read_csv('TSD_February2015.csv')
df_country_code=pd.read_csv('AllCountries_with_XWD.csv', encoding='unicode_escape')

# %%
wits_rep=pd.merge(df_wits, df_country_code, left_on='REP', right_on='ISO3', how='left')
wits_rep
# Out:
#          REP  PAR  YEAR  BOP       VALUE  \
# 0        JPN  DEU  1985  200    0.572732
# 1        JPN  DEU  1985  205  308.029000
# 2        JPN  DEU  1985  236  133.256000
# 3        JPN  DEU  1985  291    6.027000
# 4        JPN  DEU  1985  981  291.288000
# ...      ...  ...   ...  ...         ...
# 1148014  XWD  ZWE  2011  260    4.330000
# 1148015  XWD  ZWE  2011  268    1.140000
# 1148016  XWD  ZWE  2011  291   26.099000
# 1148017  XWD  ZWE  2011  981   57.119000
# 1148018  XWD  ZWE  2011  982   31.020000
#
#                                                DESCRIPTION  \
# 0                                     Total EBOPS Services
# 1                                         1 Transportation
# 2                                                 2 Travel
# 3                           11 Government services, n.i.e.
# 4        Other services, total (Sum of categories 3 to 11)
# ...                                                    ...
# ...

# %%
wits_rep
# Out:
#          REP  PAR  YEAR  BOP       VALUE  \
# 0        JPN  DEU  1985  200    0.572732
# 1        JPN  DEU  1985  205  308.029000
# 2        JPN  DEU  1985  236  133.256000
# 3        JPN  DEU  1985  291    6.027000
# 4        JPN  DEU  1985  981  291.288000
# ...      ...  ...   ...  ...         ...
# 1148014  XWD  ZWE  2011  260    4.330000
# 1148015  XWD  ZWE  2011  268    1.140000
# 1148016  XWD  ZWE  2011  291   26.099000
# 1148017  XWD  ZWE  2011  981   57.119000
# 1148018  XWD  ZWE  2011  982   31.020000
#
#                                                DESCRIPTION  \
# 0                                     Total EBOPS Services
# 1                                         1 Transportation
# 2                                                 2 Travel
# 3                           11 Government services, n.i.e.
# 4        Other services, total (Sum of categories 3 to 11)
# ...                                                    ...
# ...

# %%
wits_rep['NAME'].unique().tolist()
# Out:
# ['EBOPS: 200 Total EBOPS Services',
#  'EBOPS: 205 1 Transportation',
#  'EBOPS: 236 2 Travel',
#  'EBOPS: 291 11 Government services, n.i.e.',
#  'EBOPS: 981 Other services, total (Sum of categories 3 to 11)',
#  'EBOPS: 206 1.1 Sea transport',
#  'EBOPS: 207 1.1.1 Passenger',
#  'EBOPS: 208 1.1.2 Freight',
#  'EBOPS: 210 1.2 Air transport',
#  'EBOPS: 211 1.2.1 Passenger',
#  'EBOPS: 212 1.2.2 Freight',
#  'EBOPS: 214 1.3 Other transport',
#  'EBOPS: 245 3 Communications services',
#  'EBOPS: 249 4 Construction services',
#  'EBOPS: 253 5 Insurance services',
#  'EBOPS: 260 6 Financial services',
#  'EBOPS: 266 8 Royalties and license fees',
#  'EBOPS: 268 9 Other business services',
#  'EBOPS: 269 9.1 Merchanting and other trade-related services',
#  'EBOPS: 270 9.1.1 Merchanting',
#  'EBOPS: 271 9.1.2 Other trade-related services',
#  'EBOPS: 273 9.3 Miscellaneous business, professional, and technical services',
# ...
